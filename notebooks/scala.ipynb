# %%
# %%bash
# cat > /tmp/hello.scala <<'EOF'
# spark.sql("show tables in shop").show()
# spark.sql("select category, count(*) as products from shop.products group by category order by category").show()
# sys.exit(0)
# EOF
# spark-shell -i /tmp/hello.scala 2>&1 | grep -v -E 'WARN|SLF4J|^\s*$'
# Out:
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# Welcome to
#       ____              __
#      / __/__  ___ _____/ /__
#     _\ \/ _ \/ _ `/ __/  '_/
#    /___/ .__/\_,_/_/ /_/\_\   version 4.1.3
#       /_/
# Using Scala version 2.13.17 (OpenJDK 64-Bit Server VM, Java 17.0.20)
# Type in expressions to have them evaluated.
# Type :help for more information.
# Spark context Web UI available at http://tools:4040
# Spark context available as 'sc' (master = local[2], app id = local-1789957066063).
# Spark session available as 'spark'.
# Hive Session ID = 2d5df72a-7bc8-4130-b86a-9a5736df6e55
# +---------+-----------+-----------+
# |namespace|  tableName|isTemporary|
# +---------+-----------+-----------+
# |     shop|     orders|      false|
# |     shop|  customers|      false|
# |     shop|order_items|      false|
# |     shop|   products|      false|
# +---------+-----------+-----------+
# +-----------+--------+
# |   category|products|
# +-----------+--------+
# |      Books|      18|
# |Electronics|      18|
# |     Garden|      17|
# |       Home|      19|
# |     Sports|      17|
# |       Toys|      11|
# +-----------+--------+
