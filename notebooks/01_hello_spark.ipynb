# %% [markdown]
# # Hello Spark
# Reads the Hive table `demo` through the shared metastore.

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('hello').enableHiveSupport().getOrCreate()
spark.sql('show tables').show()
spark.sql('select * from demo order by id').show()
# Out:
# downloading https://repo1.maven.org/maven2/org/apache/httpcomponents/httpcore/4.4.13/httpcore-4.4.13.jar ...
# downloading https://repo1.maven.org/maven2/javax/annotation/javax.annotation-api/1.3.2/javax.annotation-api-1.3.2.jar ...
# downloading https://repo1.maven.org/maven2/org/apache/hive/shims/hive-shims-0.23/4.1.0/hive-shims-0.23-4.1.0.jar ...
# downloading https://repo1.maven.org/maven2/org/apache/hadoop/hadoop-yarn-server-resourcemanager/3.4.1/hadoop-yarn-server-resourcemanager-3.4.1.jar ...
# downloading https://repo1.maven.org/maven2/com/google/inject/extensions/guice-servlet/4.2.3/guice-servlet-4.2.3.jar ...
# downloading https://repo1.maven.org/maven2/com/google/inject/guice/4.2.3/guice-4.2.3.jar ...
# downloading https://repo1.maven.org/maven2/com/github/pjfanning/jersey-json/1.22.0/jersey-json-1.22.0.jar ...
# downloading https://repo1.maven.org/maven2/com/sun/jersey/contribs/jersey-guice/1.19.4/jersey-guice-1.19.4.jar ...
# ...
