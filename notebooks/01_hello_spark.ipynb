# %% [markdown]
# # Hello Spark
# Run `sh scripts/platform.sh load-sample` once first. It loads the shop dataset into Hive, and this notebook reads it through the shared metastore.

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('hello').enableHiveSupport().getOrCreate()
spark.sql('show tables in shop').show()
spark.sql('select category, count(*) as products from shop.products group by category order by category').show()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/09/20 21:48:48 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/09/20 21:48:52 WARN HiveClientImpl: Detected HiveConf hive.execution.engine is 'tez' and will be reset to 'mr' to disable useless hive logic
# Hive Session ID = 9d9cc863-d63c-4adf-b40f-5dda69cd1ede
# +---------+-----------+-----------+
# |namespace|  tableName|isTemporary|
# +---------+-----------+-----------+
# |     shop|     orders|      false|
# |     shop|  customers|      false|
# |     shop|order_items|      false|
# |     shop|   products|      false|
# +---------+-----------+-----------+
#
# +-----------+--------+
# |   category|products|
# +-----------+--------+
# |      Books|      18|
# |Electronics|      18|
# |     Garden|      17|
# |       Home|      19|
# |     Sports|      17|
# |       Toys|      11|
# +-----------+--------+
